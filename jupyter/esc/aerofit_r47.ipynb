# %%
import numpy as np

# %%
rpm = np.array([1.0, 10.0, 100.0])
thrust = np.array([2.0, 20.0, 200.0])
torque = np.array([3.0, 30.0, 300.0])

thrust_coeff = np.polyfit(rpm, thrust, 2)
torque_coeff = np.polyfit(rpm, torque, 2)

print(thrust_coeff)
print(torque_coeff)
# Out:
# [4.87332432e-17 2.00000000e+00 4.92278448e-14]
# [-1.22523507e-17  3.00000000e+00 -1.64092816e-14]
